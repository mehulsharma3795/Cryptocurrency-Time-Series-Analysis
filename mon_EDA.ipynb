# %%
import os
import numpy as np 
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# %matplotlib inline
os.chdir(r"C:\Users\mehul\Time_Series_Analysis")
from predictions import *

# %%
df_mon = predictions("monero_price.csv")
df_mon.data = df_mon.data.reindex(index=df_mon.data.index[::-1])

# %%
df_mon.description()
df_mon.missing()
df_mon.plot_daily()
df_mon.plot_monthly()
df_mon.Percent_change()
df_mon.Returns()
df_mon.stationarity_test()
# Out:
#             Open  High   Low  Close    Volume Market Cap    Mean
# 2014-05-21  2.47  2.65  1.23   1.60  2,46,540  20,79,640  1.9875
# 2014-05-22  1.59  2.19  1.36   2.10  1,32,918  13,71,470  1.8100
# 2014-05-23  2.05  3.43  2.05   2.96  2,66,852  18,16,200  2.6225
# 2014-05-24  2.92  4.01  2.62   3.70  2,48,028  26,53,720  3.3125
# 2014-05-25  4.04  4.04  2.80   3.14  2,83,545  37,74,890  3.5050
# ---------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1371 entries, 2014-05-21 to 2018-02-20
# Data columns (total 7 columns):
# Open          1371 non-null float64
# High          1371 non-null float64
# Low           1371 non-null float64
# Close         1371 non-null float64
# Volume        1371 non-null object
# Market Cap    1371 non-null object
# Mean          1371 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 85.7+ KB
# None
# ---------------------------------------------------------------
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# Mean          0
# dtype: int64
# ---------------------------------------------------------------
# C:\Users\mehul\Time_Series_Analysis\predictions.py:59: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self.data.rolmean = self.data.Mean.rolling(30).mean()
# C:\Users\mehul\Time_Series_Analysis\predictions.py:60: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self.data.rolstd = self.data.Mean.rolling(30).std()
# Results of Dickey-Fuller Test
# Test Statistic                    0.524709
# p-value                           0.985605
# #Lags Used                       24.000000
# Number of Observations Used    1346.000000
# Critical Value(1%)               -3.435218
# Critical Value(5%)               -2.863690
# Critical Value(10%)              -2.567914
# dtype: float64
# ------------------------------------------------------------------------------
# Results of KPSS Test:
# Test Statistic            2.210717
# p-value                   0.010000
# Lags Used                24.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# ------------------------------------------------------------------------------
# Results of Phillips-Perron Test:
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                  0.185
# P-value                         0.971
# Lags                               24
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.86 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# ------------------------------------------------------------------------------
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1707: InterpolationWarning: p-value is smaller than the indicated p-value
#   warn("p-value is smaller than the indicated p-value", InterpolationWarning)

# %%
df_mon.data = df_mon.data['2017-01-01':]

# %%
from produce_predict import *
#This step is parameter Selection for our furniture’s sales ARIMA Time Series Model. Our goal here is to use a “grid search” 
#to find the optimal set of parameters that yields the best performance for our model.
mon_sarima = produce_predict(df_mon.data)

# %%
mon_sarima.order()
# Out:
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(0, 0, 0, 30) - AIC:5375.013337857647
# ARIMA(0, 0, 0)x(0, 0, 1, 30) - AIC:4677.309522229592
# ARIMA(0, 0, 0)x(0, 1, 0, 30) - AIC:4423.253061025089
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(0, 1, 1, 30) - AIC:4109.351429162651
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(1, 0, 0, 30) - AIC:4435.668115707756
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(1, 0, 1, 30) - AIC:4343.317137000765
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(1, 1, 0, 30) - AIC:4120.0366479243585
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(1, 1, 1, 30) - AIC:4109.137330420616
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(0, 0, 0, 30) - AIC:4810.773334708614
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(0, 0, 1, 30) - AIC:4170.344460895321
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(0, 1, 0, 30) - AIC:3936.1825042175305
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(0, 1, 1, 30) - AIC:3656.342191129129
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(1, 0, 0, 30) - AIC:3957.6294667727707
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA(0, 0, 1)x(1, 0, 1, 30) - AIC:3943.375614078558
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(1, 1, 0, 30) - AIC:3676.480623881365
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(1, 1, 1, 30) - AIC:3658.341560488134
# ARIMA(0, 1, 0)x(0, 0, 0, 30) - AIC:3151.006876075828
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(0, 0, 1, 30) - AIC:2947.700611457318
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(0, 1, 0, 30) - AIC:3224.6187041279136
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(0, 1, 1, 30) - AIC:2788.9949570746553
# ARIMA(0, 1, 0)x(1, 0, 0, 30) - AIC:2953.8571958745774
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(1, 0, 1, 30) - AIC:2949.191059953141
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(1, 1, 0, 30) - AIC:2860.4119517466384
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(1, 1, 1, 30) - AIC:2787.1991893305863
# ARIMA(0, 1, 1)x(0, 0, 0, 30) - AIC:3113.5585798718103
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(0, 0, 1, 30) - AIC:2914.815159553489
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(0, 1, 0, 30) - AIC:3184.140472311471
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(0, 1, 1, 30) - AIC:2755.606187239081
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(1, 0, 0, 30) - AIC:2927.7909360099065
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(1, 0, 1, 30) - AIC:2916.5226759474854
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(1, 1, 0, 30) - AIC:2829.9811197556146
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(1, 1, 1, 30) - AIC:2756.0802345070188
# ARIMA(1, 0, 0)x(0, 0, 0, 30) - AIC:3159.134877001443
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(0, 0, 1, 30) - AIC:2955.1537878050917
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(0, 1, 0, 30) - AIC:3229.858931123446
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(0, 1, 1, 30) - AIC:2798.038138663785
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(1, 0, 0, 30) - AIC:2954.690376219488
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(1, 0, 1, 30) - AIC:2956.6738265562517
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(1, 1, 0, 30) - AIC:2860.7601002975593
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(1, 1, 1, 30) - AIC:2796.1315938144703
# ARIMA(1, 0, 1)x(0, 0, 0, 30) - AIC:3122.1437806189147
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(0, 0, 1, 30) - AIC:2923.2279170914226
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(0, 1, 0, 30) - AIC:3185.965885937305
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(0, 1, 1, 30) - AIC:2764.3097407748696
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(1, 0, 0, 30) - AIC:2929.52144727087
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(1, 0, 1, 30) - AIC:2924.926926001157
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(1, 1, 0, 30) - AIC:2828.97718831214
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(1, 1, 1, 30) - AIC:2764.469659254977
# ARIMA(1, 1, 0)x(0, 0, 0, 30) - AIC:3129.066963983219
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(0, 0, 1, 30) - AIC:2928.148288517773
# ARIMA(1, 1, 0)x(0, 1, 0, 30) - AIC:3206.3180493948985
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(0, 1, 1, 30) - AIC:2770.950292805489
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(1, 0, 0, 30) - AIC:2927.709498224538
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(1, 0, 1, 30) - AIC:2929.708656621491
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(1, 1, 0, 30) - AIC:2832.8240536248436
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(1, 1, 1, 30) - AIC:2769.3397355198176
# ARIMA(1, 1, 1)x(0, 0, 0, 30) - AIC:3113.2267544934416
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(0, 0, 1, 30) - AIC:2915.399178425295
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(0, 1, 0, 30) - AIC:3179.168141342533
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(0, 1, 1, 30) - AIC:2755.1144724636006
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 0, 0, 30) - AIC:2921.861388109271
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 0, 1, 30) - AIC:2917.168209574232
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 1, 0, 30) - AIC:2822.3163850535548
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 1, 1, 30) - AIC:2756.8198618785127

# %%
mon_sarima.sarima_model((1,1,1),(0,1,1,30))
mon_sarima.diagnostics()
mon_sarima.produce_forecast()
# Out:
# C:\Users\mehul\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
from fbprophet import Prophet
from prophet_model import *
mon_pro = prophet_model("monero_price.csv",955)

# %%
mon_pro.model()
mon_pro.forecast()
mon_pro.Vizualization()

# %%
from VaR import *
var = Var(df_mon.data)

# %%
var.var_cov(100)
var.hist_sim(100)
# Out:
# Confidence Interval      Value At Risk
# ---------------------  ---------------
# 90%                           -6.50726
# 95%                           -8.6138
# 99%                          -12.5653
# Confidence Interval      Value At Risk
# ---------------------  ---------------
# 90%                           -5.50561
# 95%                           -8.0474
# 99%                          -13.5216

# %%
var.monte_carlo()
# Out:
# Simulated VAR is  -13.623085264030562
